# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import utils as u
import soundfile as sf

# %% [markdown]
# # First Test
# Making sure that the audio output is working

# %%
ex, sr = librosa.load('Sounds/Guitar_Heavy.mp3', sr=44100)

# S = np.abs(librosa.stft(ex))

# max = S.max()

# S_dB = librosa.amplitude_to_db(S, ref=np.max)

# u.show_spectrogram(S_dB)

# S_dB[S_dB<-40] = -80

# u.show_spectrogram(S_dB)

# S_c = librosa.griffinlim(librosa.db_to_amplitude(S_dB) * max)

# u.show_spectrogram_audiodata(S_c)

sf.write('test1.mp3', ex, 44100, format='MP3')

# %%
sf.available_formats()
# Out:
# {'AIFF': 'AIFF (Apple/SGI)',
#  'AU': 'AU (Sun/NeXT)',
#  'AVR': 'AVR (Audio Visual Research)',
#  'CAF': 'CAF (Apple Core Audio File)',
#  'FLAC': 'FLAC (Free Lossless Audio Codec)',
#  'HTK': 'HTK (HMM Tool Kit)',
#  'SVX': 'IFF (Amiga IFF/SVX8/SV16)',
#  'MAT4': 'MAT4 (GNU Octave 2.0 / Matlab 4.2)',
#  'MAT5': 'MAT5 (GNU Octave 2.1 / Matlab 5.0)',
#  'MPC2K': 'MPC (Akai MPC 2k)',
#  'MP3': 'MPEG-1/2 Audio',
#  'OGG': 'OGG (OGG Container format)',
#  'PAF': 'PAF (Ensoniq PARIS)',
#  'PVF': 'PVF (Portable Voice Format)',
#  'RAW': 'RAW (header-less)',
#  'RF64': 'RF64 (RIFF 64)',
#  'SD2': 'SD2 (Sound Designer II)',
#  'SDS': 'SDS (Midi Sample Dump Standard)',
#  'IRCAM': 'SF (Berkeley/IRCAM/CARL)',
#  'VOC': 'VOC (Creative Labs)',
#  'W64': 'W64 (SoundFoundry WAVE 64)',
#  'WAV': 'WAV (Microsoft)',
#  'NIST': 'WAV (NIST Sphere)',
#  'WAVEX': 'WAVEX (Microsoft)',
#  'WVE': 'WVE (Psion Series 3)',
#  'XI': 'XI (FastTracker 2)'}

# %%
u.show_spectrogram_filepath('Sounds/Strings.mp3')
